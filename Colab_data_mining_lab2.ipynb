# %%
import pandas as pd

# %%
file_path = "/content/titanic.csv"

# %%
data = pd.read_csv(file_path)

# %%
summary = data.describe()

# %%
print(summary)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(data.describe(include=['object']))
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['Age'].dropna(), bins=20, edgecolor='black', color='skyblue')
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.show()

# %%
plt.figure(figsize=(6, 4))

# %%
plt.boxplot(data['Age'].dropna(), patch_artist=True, boxprops=dict(facecolor='lightgreen'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ab14037b650>,
#   <matplotlib.lines.Line2D at 0x7ab140384410>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ab140384f50>,
#   <matplotlib.lines.Line2D at 0x7ab140385a10>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7ab14037af10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ab1403864d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ab140386ed0>],
#  'means': []}

# %%
plt.title('Passenger Class Distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Class Distribution')

# %%
plt.xlabel('Class')
# Out:
# Text(0.5, 0, 'Class')

# %%
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.xticks(rotation=0)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(data[['Age', 'Fare', 'SibSp', 'Parch']].dropna())

# %%
plt.show()

# %%
correlation_matrix = data[['Age', 'Fare', 'SibSp', 'Parch']].corr()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
# Out:
# <Axes: >

# %%
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt.show()

# %%
sns.violinplot(x='Pclass', y='Age', data=data, palette='muted')
# Out:
# <ipython-input-62-a43a0372f681>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Pclass', y='Age', data=data, palette='muted')
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
plt.title('Age Distribution by Passenger Class')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Passenger Class')

# %%
plt.show()

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
file_path = "/content/titanic.csv"

# %%
data = pd.read_csv(file_path)

# %%
print("Statistical Summary:")
# Out:
# Statistical Summary:

# %%
print(data.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print("\nCategorical Summary:")
# Out:
# Categorical Summary:

# %%
print(data.describe(include=['object']))
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
plt.hist(data['Age'].dropna(), bins=20, edgecolor='black', color='skyblue')
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.show()

# %%
plt.figure(figsize=(6, 4))

# %%
data['Pclass'].value_counts().plot(kind='bar', color='lightcoral')
# Out:
# <Axes: xlabel='Pclass'>

# %%
plt.title('Passenger Class Distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Class Distribution')

# %%
plt.xlabel('Class')
# Out:
# Text(0.5, 0, 'Class')

# %%
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.xticks(rotation=0)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.show()

# %%
plt.figure(figsize=(6, 4))

# %%
plt.boxplot(data['Age'].dropna(), patch_artist=True,boxprops=dict(facecolor='lightgreen'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff5da466390>,
#   <matplotlib.lines.Line2D at 0x7ff5da33dd90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff5da33e7d0>,
#   <matplotlib.lines.Line2D at 0x7ff5da33f1d0>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7ff5da312250>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff5da33fb10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff5da3503d0>],
#  'means': []}

# %%
plt.title('Box Plot of Age')
# Out:
# Text(0.5, 1.0, 'Box Plot of Age')

# %%
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.show()

# %%
sns.pairplot(data[['Age', 'Fare', 'SibSp', 'Parch']].dropna())

# %%
plt.show()

# %%
correlation_matrix = data[['Age', 'Fare', 'SibSp', 'Parch']].corr()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
# Out:
# <Axes: >

# %%
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt.show()

# %%
sns.countplot(x='Survived', data=data, palette='Set2')
# Out:
# <ipython-input-47-abdcbc419fe0>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=data, palette='Set2')
# <Axes: xlabel='Survived', ylabel='count'>

# %%
plt.title('Survival Count')
# Out:
# Text(0.5, 1.0, 'Survival Count')

# %%
plt.xlabel('Survived')
# Out:
# Text(0.5, 0, 'Survived')

# %%
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.show()

# %%
sns.violinplot(x='Pclass', y='Age', data=data, palette='muted')
# Out:
# <ipython-input-52-a43a0372f681>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Pclass', y='Age', data=data, palette='muted')
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
plt.title('Age Distribution by Passenger Class')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Passenger Class')

# %%
plt.show()
